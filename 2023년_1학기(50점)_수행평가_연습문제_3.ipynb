# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2023_DataScience/blob/main/2023%EB%85%84_1%ED%95%99%EA%B8%B0(50%EC%A0%90)_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #서울 열린 데이터광장 사이트에서 '서울시 전기차 충전소 정보' 파일을 다운로드하고 다음과 같이 데이터를 만들어 'seoul_car.xlsx'로 저장한다![20230523_113842.png](data:image/png;base64,...)

# %% [markdown]
# #문제1. 폰트설치(2점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(2점)

# %% [markdown]
# # 문제2. 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출(2점)

# %%
#문제2번(2점)

# %% [markdown]
# #문제3. #파일을 바로 업로드할 때(업로드는 1번만 실행할 것)

# %%
#문제3번(1점)

# %% [markdown]
# #문제4. 서울의 전기자동차 충전소 현황 파일(seoul_car.xlsx)을 판다스 라이브러리를 이용해 읽는다.(5점)

# %%
#문제4번(5점)

# %% [markdown]
# #문제5. 주소에서 구 이름만 추출하여 '지역구' 칼럼을 만든다.(5점)

# %%
#문제5번(5점)

# %% [markdown]
# #문제6. 데이터 중 24시간 이용가능한 데이터만 추출하여 새로운 데이터프레임(df1)으로 만든다

# %% [markdown]
# #문제7. 지역구별로 개수를 세서 새로운 데이터프레임(df2)을 만든다.(5점)

# %%
#문제7번(5점)

# %% [markdown]
# #문제8. 새로 만들어진 데이터프레임을 지역구별로 개수가 많은 구부터 내림차순으로 정렬한다.(5점)

# %%
#문제8번(5점)

# %% [markdown]
# #문제9. 위의 데이터프레임을 그래프로 그림처럼 시각화한다.(5점)![20230523_121001.png](data:image/png;base64,...)

# %%
#문제9번(5점)

# %% [markdown]
# #문제10. 원하는 지역의 구이름을 입력받아 그 지역의 충전소 현황을 새로운 데이터프레임으로 만든다.(5점)

# %% [markdown]
# 문제11. 데이터프레임의 위도, 경도 데이터를 이용하여 지도로 시각화한다.(10점)![20230523_121650.png](data:image/png;base64,...)

# %%
#문제10번(10점)
