# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2023_DataScience/blob/main/2023%EB%85%84_1%ED%95%99%EA%B8%B0(50%EC%A0%90)_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #서울 열린 데이터광장 사이트에서 '서울시 지하철 역사정보'와 '서울시 지하철호선별 역별 승하차 인원 정보' 파일을 다운받아 아래와 같이 엑셀파일로 만들어 'seoul_subway.xlsx'로 저장하시오.
# ![20230530_083219.png](data:image/png;base64,...)

# %% [markdown]
# #문제1. 폰트설치(2점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(2점)

# %% [markdown]
# # 문제2. 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출(2점)

# %%
#문제2번(2점)

# %% [markdown]
# #문제3. #파일을 바로 업로드할 때(업로드는 1번만 실행할 것)

# %%
#문제3번(1점)

# %% [markdown]
# #문제4. 서울의 지하철 역사의 위치와 승객수 현황 파일(seoul_subway.xlsx)을 판다스 라이브러리를 이용해 읽는다.(5점)

# %%
#문제4번(5점)

# %% [markdown]
# #승차승객수와 하차승객수를 더해 총승객수를 데이터프레임에 추가한다.

# %% [markdown]
# #문제5. 승차총승객수와 하차총승객수가 20000명이상인 역만 필터링하여 새로운 데이터프레임(df1)으로 만든다.(5점)

# %%
#문제5번(5점)

# %% [markdown]
# #문제6. df1의 데이터 중 2호선 데이터만 추출하여 새로운 데이터프레임(df2)으로 만든다

# %% [markdown]
# #2호선의 총승객수가 가장 많은 역의 이름을 찾아 출력하시오.
# 예) 2호선의 승객수가 가장 많은 역은 강남역입니다

# %% [markdown]
# #문제7. df의 데이터 중 호선별로 개수를 세서 새로운 데이터프레임(df3)을 만든다.(5점)

# %%
#문제7번(5점)

# %% [markdown]
# #문제8. df3 데이터프레임을 노선별로 개수가 많은 노선부터 내림차순으로 정렬한다.(5점)

# %%
#문제8번(5점)

# %% [markdown]
# #문제9. 위의 데이터프레임을 그래프로 그림처럼 시각화한다.(5점)
# ![20230612_085437.png](data:image/png;base64,...)

# %%
#문제9번(5점)

# %% [markdown]
# #df의 데이터 중 호선별로 총승객수의 합을 구해 내림차순으로 정렬한 후 새로운 데이터프레임(df4)을 만든다.(5점)

# %% [markdown]
# #df4 데이터프레임을 이용해 그래프로 그림처럼 시각화한다.(5점)
# ![20230612_085556.png](data:image/png;base64,...)

# %% [markdown]
# #문제10. 승하차승객이 20000명이상인 데이터(df1)에서 원하는 지하철 노선의 이름을 입력받아 지하철 노선의 위치를 지도에 마커로 표시한다.(5점)
# ![20230612_085656.png](data:image/png;base64,...)

# %%
#문제10번(10점)
