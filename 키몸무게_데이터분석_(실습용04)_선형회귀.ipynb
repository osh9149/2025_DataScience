# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2023_DataScience/blob/main/%ED%82%A4%EB%AA%B8%EB%AC%B4%EA%B2%8C_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_(%EC%8B%A4%EC%8A%B5%EC%9A%A904)_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <3> 키-몸무게 데이터
#
# "키와 몸무게는 어떤 상관관계가 있을까?"
#
# ### 🚩 파일 다운로드 [>> 클릭]
# [출처 - 공공데이터포털](https://www.data.go.kr/data/15051017/fileData.do)

# %% [markdown]
# # 0. 한글폰트 설정
#
#
# 1️⃣   한글 폰트 코드 실행
# ```
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# ```

# %%
# 셀1- 한글 폰트 설정
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,505 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# 2️⃣ **런타임 - 런타임 다시시작**
#
# ```
# import os
# os.kill(os.getpid(), 9)
# ```

# %%
# 셀2-런타임 다시시작

# %% [markdown]
# 3️⃣  **글꼴 지정 명령어**
# ```
# import matplotlib.pyplot as plt
#
# plt.rc('font', family='NanumBarunGothic')
# ```

# %%
# 셀3-폰트 지정

# %% [markdown]
# # 1. 파일 업로드
#
# ```
# from google.colab import files
# uploaded = files.upload()
# ```

# %%
#셀4-파일 업로드
# Out:
#      <input type="file" id="files-3a9eaf36-ab1c-4dd9-bde0-8387c5b952db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a9eaf36-ab1c-4dd9-bde0-8387c5b952db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### csv 파일을 읽어서 DataFrame으로 변환하기
#
# ```
# import pandas as pd
#
# data = pd.read_excel('파일 이름')
# data = pd.read_csv('파일 이름', encoding='cp949')
# ```

# %%
#셀5=-csv 파일 읽기

# %%
# 데이터의 기본정보 출력
# Out:
#        고유식별번호(ID)       최종가중치 학교고유번호(ID)      도시규모 도시규모별분석용   학년도 광역시도  \
# 0     Aa011남10101  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 1     Aa011남10102  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 2     Aa011남10103  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 3     Aa011남10104  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 4     Aa011남10105  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# ...           ...         ...        ...       ...      ...   ...  ...
# 9681  Ac343남30106   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9682  Ac343남30107   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9683  Ac343남30108   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9684  Ac343여30101   23.325794       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9685  Ac343여30102   23.325794       Ac34  대도시/중소도시   특별/광역시  2015   서울
#
#            시도별  학교급별       학교명  ...      키   몸무게  혈당식전(mgdl) 총콜레스테롤(mgdl)  \
# ...

# %% [markdown]
# #### 데이터 기본정보 파악하기
# ```
# data.info
# ```

# %%
# Out:
# <bound method DataFrame.info of        고유식별번호(ID)       최종가중치 학교고유번호(ID)      도시규모 도시규모별분석용   학년도 광역시도  \
# 0     Aa011남10101  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 1     Aa011남10102  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 2     Aa011남10103  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 3     Aa011남10104  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# 4     Aa011남10105  169.550665       Aa01  대도시/중소도시   특별/광역시  2015   서울
# ...           ...         ...        ...       ...      ...   ...  ...
# 9681  Ac343남30106   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9682  Ac343남30107   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9683  Ac343남30108   25.790895       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9684  Ac343여30101   23.325794       Ac34  대도시/중소도시   특별/광역시  2015   서울
# 9685  Ac343여30102   23.325794       Ac34  대도시/중소도시   특별/광역시  2015   서울
#
#            시도별  학교급별       학교명  ...      키   몸무게  혈당식전(mgdl) 총콜레스테롤(mgdl)  \
# ...

# %% [markdown]
# #### Q. 데이터타입?
# ```
# data.describe()
# ```

# %%
# Out:
#              최종가중치     학년도         학교급별           학년            반  \
# count  9686.000000  9686.0  9686.000000  9686.000000  9686.000000
# mean    104.894487  2015.0     1.995767     2.567933     2.659096
# std      39.376988     0.0     0.856499     1.414243     2.601067
# min      23.325794  2015.0     1.000000     1.000000     1.000000
# 25%      76.966829  2015.0     1.000000     1.000000     1.000000
# 50%      99.963287  2015.0     2.000000     2.000000     1.000000
# 75%     133.231158  2015.0     3.000000     3.000000     3.000000
# max     248.300844  2015.0     3.000000     6.000000    15.000000
#
#                  키          몸무게  혈당식전(mgdl)  총콜레스테롤(mgdl)  간기능(AST)단위(UL)  \
# count  9686.000000  9682.000000   338.00000    339.000000      336.000000
# mean    154.564444    50.207591    92.14497    173.516519       27.824405
# std      16.968590    17.075953    10.49571     32.567571       19.327395
# min     107.700000    15.900000    65.00000    102.000000       11.000000
# ...

# %% [markdown]
# ## ❓ 키와 몸무게데이터만 추출?
# ```
# data1=data[['키','몸무게']]
# data1
# ```

# %%
# Out:
#           키   몸무게
# 0     125.8  27.3
# 1     124.3  25.4
# 2     119.2  23.5
# 3     115.0  20.0
# 4     120.0  33.5
# ...     ...   ...
# 9681  176.1  50.4
# 9682  174.1  88.8
# 9683  169.5  63.2
# 9684  159.2  52.9
# 9685  162.0  67.7
#
# [9686 rows x 2 columns]

# %%
# Out:
# 0       125.8
# 1       124.3
# 2       119.2
# 3       115.0
# 4       120.0
#         ...
# 9681    176.1
# 9682    174.1
# 9683    169.5
# 9684    159.2
# 9685    162.0
# Name: 키, Length: 9686, dtype: float64

# %% [markdown]
# ```
# data1.isnull()
# ```

# %%
# Out:
#           키    몸무게
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ...     ...    ...
# 9681  False  False
# 9682  False  False
# 9683  False  False
# 9684  False  False
# 9685  False  False
#
# [9686 rows x 2 columns]

# %% [markdown]
# ```
# data1[data1['키'].isnull()]
# ```

# %%
# Out:
# Empty DataFrame
# Columns: [키, 몸무게]
# Index: []

# %%
# Out:
#           키  몸무게
# 1205  145.5  NaN
# 1206  164.2  NaN
# 1207  149.3  NaN
# 1208  155.5  NaN

# %% [markdown]
# #Nan이란 Not a number의 약자로 0/0처럼 수학적으로 정의가 되지 않는 값
# # 결측치(Nan)가 하나라도 있는 행을 제거
# 데이터프레임.dropna(axis='rows')
#
# # 결측치(Nan)가 하나라도 있는 열을 제거
# 데이터프레임.dropna(axis='columns')

# %%
#결측치가 있는 행을 제거

# %% [markdown]
# ```
# data1[data1['몸무게'].isnull()]
# ```

# %%
#데이터 프레임에 결측치가 없는 지 확인
# Out:
# Empty DataFrame
# Columns: [키, 몸무게]
# Index: []

# %% [markdown]
# ```
# import seaborn as sns
# sns.jointplot(x='키', y='몸무게', data=data1)
# plt.show()
# ```

# %%
#키와 몸무게로 그래프를 그림

# %% [markdown]
# #데이터의 상관관계를 알아봄
# ```
# data.corr()
# ```

# %%
# Out:
#             키       몸무게
# 키    1.000000  0.849006
# 몸무게  0.849006  1.000000

# %% [markdown]
# ```
# X=data1[['키']]
# y=data1['몸무게']
# ```

# %%
# 머신러닝 알고리즘에 학습시킬 속성은 이차원 형태여야 함

# %% [markdown]
# #훈련 데이터, 테스트 데이터 분리
# ```
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=27)
# ```

# %% [markdown]
# #훈련데이터, 테스트데이터 출력
# ```
# X_train
# X_test
# y_train
# y_test
# ```

# %% [markdown]
# #선형 회귀 모델 생성
# ```
# from sklearn.linear_model import LinearRegression
#
# my_lig=LinearRegression()
# ```

# %% [markdown]
# #선형 회귀 모델 학습시키기
# ```
# my_lig.fit(X_train, y_train)
# ```

# %%
# Out:
# LinearRegression()

# %% [markdown]
# #학습 결과(추세선) 확인하기
# ```
# 기울기 : 모델이름.coef_
# y절편 : 모델이름.intercept_
# ```

# %%
# Out:
# [0.85769923] -82.32184316602033

# %% [markdown]
# #작성한 모델로 예측 해보기
# ```
# my_lig.predict([[160]])
# ```

# %% [markdown]
# #선형회귀 모델 평가하기
# ```
# y_pred=my_lig.predict(X_test)
# ```

# %%
# 전체 테스트데이터의 예측값을 y_pred에 저장하기

# %% [markdown]
# ```
# # 테스트 데이터의 실제값 : 파란색 산점도
# plt.plot(X_test, y_test, 'bo')
#
# # 테스트 데이터의 예측값 : 빨간색 선 그래프
# plt.plot(X_test, y_pred,'r')
#
# plt.xlabel('키')
# plt.ylabel('몸무게')
# plt.legend()
# plt.show()
# ```

# %%
# 테스트 데이터의 실제값 : 파란색 산점도


# 테스트 데이터의 예측값 : 빨간색 선 그래프
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #모델 평가하기
# ```
# my_lig.score(X_test, y_test)
# ```
