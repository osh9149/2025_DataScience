# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2023_DataScience/blob/main/2023%EB%85%84_1%ED%95%99%EA%B8%B0(50%EC%A0%90)_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EB%AC%B8%EC%A0%9C(%EC%A7%9D%EC%88%98%ED%98%95).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #https://github.com/osh9149/2023_DataScience.git 에서 다운로드

# %% [markdown]
# #대학정보공시 사이트에서 '전국 대학 등록금 정보'와 '대학교 개황정보'파일을 다운받아 아래와 같이 엑셀파일 'korea_univ_02.xlsx'를 만들었다.

# %% [markdown]
# #위도와 경도 데이터가 없는 경우 구글 확장기능을 사용하여 데이터를 찾아 데이터를 만든다.

# %% [markdown]
# ![20230612_131749.png](data:image/png;base64,...)

# %% [markdown]
# #문제1. 폰트설치(1점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(1점)

# %% [markdown]
# # 문제2. 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출(1점)

# %%
#문제2번(1점)

# %% [markdown]
# #문제3. #파일을 바로 업로드할 때(업로드는 1번만 실행할 것)(1점)

# %%
#문제3번(1점)

# %% [markdown]
# #문제4. 데이터파일을(korea_univ.xlsx)을 판다스 라이브러리를 이용해 읽는다.(2점)

# %%
#문제4번(2점)

# %% [markdown]
# #문제5. 데이터프레임(df)에서 등록금이 가장 높은 학교와 가장 적은 학교를 찾아 아래와 같이 출력한다.(3점)

# %%
#문제5번(3점)

# %% [markdown]
# #문제6.지역별로 대학교의 개수를 카운트하여 데이터를 내림차순으로 정렬하여 새로운 데이터프레임(df1)으로 만든다.(4점)

# %%
#문제6번(4점)

# %% [markdown]
# #문제7. 데이터프레임(d1f)에서 대학교의 개수가 가장 적은 지역을 찾아 다음과 같이 출력한다.(4점)
# 예) 전국에서 대학교의 수가 가장 적은 지역은 세종입니다.

# %%
#문제7번(4점)

# %% [markdown]
# #문제8. 위의 데이터프레임(df1)을 그래프로 그림처럼 시각화한다.(4점)
# 가로막대그래프 -> barh
# ![20230614_083843.png](data:image/png;base64,...)

# %%
#문제8번(4점)

# %% [markdown]
# #문제9. 데이터프레임(df)에서 의학 등록금이 있는 학교만 새로운 데이터프레임 df2로 만든다.(3점)

# %%
#문제9번(3점)

# %% [markdown]
# #문제10. 데이터프레임(df2)에서 의학 등록금을 작은순에서 많은 순으로 오름차순으로 정렬한 후 df2를 출력한다.(3점)

# %%
#문제10번(3점)

# %% [markdown]
# #문제11. 데이터프레임(df2)에서 의학 계열 등록금이 가장 많은 학교와 가장 적은 학교를 찾아 다음과 같이 출력한다.(4점)
# 출력결과)전국 대학교 중 의학 등록금이 가장 높은 대학은 이화여자대학교이고 가장 낮은 대학은 전남대학교입니다.

# %%
#문제11번(4점)

# %% [markdown]
# #문제12. 위의 데이터프레임(df2)을 그래프로 그림처럼 시각화한다.(4점)
# ![20230614_082419.png](data:image/png;base64,...)

# %%
#문제12번(4점)

# %% [markdown]
# #문제13. 데이터프레임(df2)을 그림처럼 그룹화(평균을 계산)하여 새로운 데이터프레임(df3)를 만든 후 의학을 기준으로 내림차순으로 졍렬하여 출력한다. (4점)
# ![20230614_073748.png](data:image/png;base64,...)

# %%
#문제13번(4점)

#groupby('컬럼').count() : 개수
#groupby('컬럼').sum() : 합계
#groupby('컬럼').mean() : 평균

# %% [markdown]
# #문제14. 데이터프레임(df3)에서 국립대의 의학등록금과 사립대의 의학 등록금의 차이를 계산하여 아래와 같이 출력한다. 이때 차이값은 print문에서 %d로 출력한다.(4점)
# 예) 사립의대의 등록금은 국립의대 등록금보다 평균 2267789원 비쌉니다.

# %%
#문제14번(4점)

# %% [markdown]
# #문제15. 데이터프레임(df2)에서 원하는 지역의 이름을 입력받아 해당하는 지역의 데이터만 새로운 데이터프레임(df4)로 만든다.(4점)
# 예) '서울' 입력하여 확인

# %%
#문제15번(4점)

# %% [markdown]
# #문제16. 데이터프레임(df4)에서 위도 경도를 찾아 지도에 마커로 표시(zoom_start=11)하고 팝업에 학교이름이 보이도록 한다.(4점)
# 아이콘 변경 -> icon=folium.Icon(icon = 'home', color='red')

# %% [markdown]
# ![20230614_085949.png](data:image/png;base64,...)

# %%
#문제16번(4점)
