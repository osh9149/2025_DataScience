# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2025_DataScience/blob/main/2025%EB%85%84_3%ED%95%99%EB%85%84_1%ED%95%99%EA%B8%B0_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EB%AC%B8%EC%A0%9C(%ED%99%80%EC%88%98%ED%98%95_%ED%95%99%EB%B2%88%EC%9D%B4%EB%A6%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##2025년 3학년 1학기 수행평가(50점) 문제 : 기본점수 5점 + 문제15번까지(45점)

# %% [markdown]
# 공공데이터포털에서 '경찰청_범죄 발생 지역별 통계.xlsx'와 '경찰청_전국 지구대 파출소 주소 현황.csv에 관한 파일을 다운받아 제공합니다.

# %% [markdown]
# #문제1. 폰트설치(1점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(1점)

# %% [markdown]
# # 문제2번(2점). 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출

# %%
#문제2번(2점)

# %% [markdown]
# #문제3번(2점). #'경찰청_범죄 발생 지역별 통계.xlsx'을 업로드함.  파일을 바로 업로드할 때(업로드는 1번만 실행할 것)(1점)

# %%
#문제3번(2점)

# %% [markdown]
# #문제4번(2점). 데이터파일을(경찰청_범죄 발생 지역별 통계.xlsx)을 판다스 라이브러리를 이용해 읽는다.

# %%
#문제4번(2점)

# %% [markdown]
# #문제5번(4점).데이터프레임(df)을 '범죄대분류'로 그룹화하여 sum함수를 이용해 새로운 데이터프레임(df1)를 만든 후 구이름을 입력받아 df1를 '구이름'를 기준으로 내림차순으로 정렬하여 df1.loc를 이용하여 그림과 같이 출력한다.
# 구이름 : 서울성동구 입력
# ![image.png](data:image/png;base64,...)

# %%
#문제5번(4점)

# %% [markdown]
# #문제6번(4점). 데이터프레임(df1)에서 위에서 입력받은 구이름 데이터 중 가장 많은 범죄와 가장 적은 범죄를 찾아 다음과 같이 출력한다.
# 예) 서울성동구에서 가장 많은 범죄는 지능범죄이고 가장 적은 범죄는 환경범죄입니다.

# %%
#문제6번(4점)

# %% [markdown]
# #문제7번(4점). 데이터프레임(df1)에서 위에서 입력받은 구이름 데이터 중 범죄 건수가 가장 큰 건수와 가장 작은 건수의 차이를 출력한다..
# 예) 서울성동구에서 가장 많은 범죄건수와 가장 적은 범죄건수의 차이는 2482 건입니다.

# %%
#문제7번(4점)

# %% [markdown]
# #문제8번(4점). 위의 데이터프레임(df1)에서 위에서 입력받은 구이름 데이터 중 '범죄건수' 데이터를 이용하여 그래프로 그림처럼 시각화한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제8번(4점)

# %% [markdown]
# #문제9번(4점). 데이터프레임(df)에서 구이름을 입력받아 데이터가 500건 이상인 데이터만 새로운 프레임(df3)를 만든 후 df3를 구이름을 기준으로 내림차순으로 정렬하여 df3를 그림과 같이 출력한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제9번(4점)

# %% [markdown]
# #문제10번(4점). 위의 데이터프레임(df3)의 '범죄중분류'를 이용하여 그림처럼 그래프로 시각화한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제10번(4점)

# %% [markdown]
# ### 경찰청_전국 지구대 파출소 주소 현황.csv --------------------------------------------

# %% [markdown]
# #문제11번(1점). 파일 '경찰청_전국 지구대 파출소 주소 현황.csv'를 업로드한다.

# %%
#문제11번(1점)

# %% [markdown]
# #문제12번(1점). 파일 '경찰청_전국 지구대 파출소 주소 현황.csv'를 업로드하고 파일을 읽어 데이터프레임(df)를 출력한다.

# %%
#문제12번(1점)

# %% [markdown]
# #문제13번(4점). 데이터프레임(df)에서 '시도청'이 '서울청'이고 '구분'이 '파출소'인 데이터만 새로운 df1 프레임으로 만든다.
# ![image.png](data:image/png;base64,...)

# %%
#문제13번(4점)

# %% [markdown]
# #문제14번(4점). 데이터프레임(df1)의 '주소'에서 구임을 입력받아 새로운 df2 프레임으로 만든다.
# ![image.png](data:image/png;base64,...)

# %%
#문제14번(4점)

# %% [markdown]
# #문제15번(4점). 데이터프레임(df2)에서 '위도','경도'를 찾아 지도에 마커로 표시(zoom_start=15)하고 팝업에 '주소'가 보이도록 한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제15번(4점)
