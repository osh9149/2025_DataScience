# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2025_DataScience/blob/main/2025%EB%85%84_3%ED%95%99%EB%85%84_1%ED%95%99%EA%B8%B0_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EB%AC%B8%EC%A0%9C(%EC%A7%9D%EC%88%98%ED%98%95_%ED%95%99%EB%B2%88%EC%9D%B4%EB%A6%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##2025년 3학년 1학기 수행평가(50점) 문제 : 기본점수 5점 + 문제15번까지(45점)

# %% [markdown]
# #공공데이터포털에서 제주도장소(POI)데이터.xlsx'와 '제주_관광객_소비패턴_데이터.csv'에 관한 파일을 다운받아 제공합니다.

# %% [markdown]
# #문제1. 폰트설치(1점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(1점)

# %% [markdown]
# # 문제2번(2점). 데이터 분석 및 그래프, 지도 시각화를 위한 라이브러리를 호출

# %%
#문제2번(2점)

# %% [markdown]
# #문제3번(2점). #제주_관광객_소비패턴_데이터.csv을 업로드함.  파일을 바로 업로드할 때(업로드는 1번만 실행할 것)(1점)

# %%
#문제3번(2점)

# %% [markdown]
# #문제4번(2점). 데이터파일을(제주_관광객_소비패턴_데이터.csv)을 판다스 라이브러리를 이용해 읽는다.

# %%
#문제4번(2점)

# %% [markdown]
# #문제5번(2점).'카드이용금액'를 기준으로 내림차순으로 정렬하여 새로운 데이터프레임(df1)으로 만든다.

# %%
#문제5번(2점)

# %% [markdown]
# #문제6번(4점). 데이터프레임(df1)에서 '카드이용금액'이 가장 많은 업종과 가장 적은 업종을 찾아 다음과 같이 출력한다.
# 예) 제주도 관광객 카드이용금액이 가장 많은 업종은 기념품 점이고 가장 적은 업종은 약국입니다.

# %%
#문제6번(4점)

# %% [markdown]
# #문제7번(4점). 데이터프레임(df1)에서 '카드이용금액'가장 큰 금액과 가장 적은 금액의 차이를 출력한다..
# 예) 제주도 관광객 카드이용금액의 가장 큰 금액과 가장 적은 금액의 차이는 64,241,600입니다.

# %%
#문제7번(4점)

# %% [markdown]
# #문제8번(4점). 데이터프레임(df1)을 '제주 중분류'로 그룹화하여 sum함수를 이용해 새로운 데이터프레임(df2)를 만든 후 df2를 '카드이용금액'를 기준으로 내림차순으로 정렬하여 df2를 loc를 활용하여 그림과 같이 df2를 만들어서 출력한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제8번(4점)

# %% [markdown]
# #문제9번(4점). 위의 데이터프레임(df2)의 '카드이용금액' 데이터를 이용하여 그래프로 그림처럼 시각화한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제9번(4점)

# %% [markdown]
# #문제10번(4점). 데이터프레임(df1)을 '제주 중분류'로 그룹화하여 count함수를 이용해 새로운 데이터프레임(df3)를 만든 후 df3를 '카드이용건수'를 기준으로 내림차순으로 정렬하여 df3를 출력한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제10번(4점)

# %% [markdown]
# #문제11번(4점). 위의 데이터프레임(df3)의 '카드이용건수'를 이용하여 그림처럼 그래프로 시각화한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제11번(4점)

# %% [markdown]
# # 제주도장소(POI)데이터.xlsx --------------------------------------------

# %% [markdown]
# #문제12번(1점). 파일 '제주관광정보시스템(VISIT JEJU)_여행장소.xlsx'를 업로드한다.

# %%
#문제12번(1점)

# %% [markdown]
# #문제13번(1점). 파일 '제주관광정보시스템(VISIT JEJU)_여행장소.xlsx'를 업로드하고 파일을 읽어 데이터프레임(df)를 출력한다.

# %%
#문제13번(1점)

# %% [markdown]
# #문제14번(4점). 데이터프레임(df)에서 '지번주소'중 지역명을 입력받아 '장소명'에 '성산'이 포함된 지역만 새로운 df1 프레임으로 만든다.
# - '성산리' 입력
# ![image.png](data:image/png;base64,...)

# %%
#문제14번(4점)

# %% [markdown]
# #문제15번(4점). 데이터프레임(df1)에서 '위도','경도'를 찾아 지도에 마커로 표시(zoom_start=14)하고 팝업에 '장소명'이 보이도록 한다.
# ![image.png](data:image/png;base64,...)

# %%
#문제15번(4점)
