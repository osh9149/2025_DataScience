# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2023_DataScience/blob/main/%EA%B8%B0%EC%98%A8%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
for line in data:
    print(line)

f.close()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['2007-07-24', '108', '23.4', '21.1', '26.7']
# ['2007-07-25', '108', '24.7', '23.2', '26.7']
# ['2007-07-26', '108', '26.7', '23', '31.2']
# ['2007-07-27', '108', '26.9', '25.1', '29.7']
# ['2007-07-28', '108', '25.1', '24.1', '26.2']
# ['2007-07-29', '108', '24.6', '21.7', '27.2']
# ['2007-07-30', '108', '26.4', '22.2', '31.2']
# ['2007-07-31', '108', '26.4', '23.5', '29.8']
# ['2007-08-01', '108', '27.2', '25.1', '30.1']
# ['2007-08-02', '108', '27.8', '25.7', '30.2']
# ['2007-08-03', '108', '27.5', '25.2', '32.2']
# ['2007-08-04', '108', '24.5', '22.2', '26.1']
# ['2007-08-05', '108', '24.8', '22.2', '27.7']
# ['2007-08-06', '108', '25.7', '24', '29.3']
# ['2007-08-07', '108', '23.8', '22.3', '25.2']
# ['2007-08-08', '108', '25.3', '21.8', '27.7']
# ['2007-08-09', '108', '26.1', '22.2', '29.2']
# ['2007-08-10', '108', '27.7', '25.7', '31']
# ['2007-08-11', '108', '28.7', '25.5', '33']
# ['2007-08-12', '108', '26.2', '24.6', '28.1']
# ...

# %%
import csv
date=input('년도-월-일(2019-05-05 형태로 입력)')
f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
for line in data:
    if date==line[0]:
        print(line)

f.close()
# Out:
# 년도-월-일(2019-05-05 형태로 입력)2020-01-25
# ['2020-01-25', '108', '4.3', '0.6', '8.8']

# %%
import csv
f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
next(data)
max_temp=0
max_date=''
for line in data:
    if line[-1]!='' and max_temp<float(line[-1]):
        max_temp=float(line[-1])
        max_date=line[0]

print(max_temp, max_date)

f.close()
# Out:
# 39.6 2018-08-01

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
next(data)
result=[]

for line in data:
    if line[-1]!='':
        result.append(float(line[-1]))
# print(len(result))
# print(result)
plt.figure(figsize=(10,2))
plt.plot(result,'r')
plt.show()
f.close()

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
next(data)
result=[]

for line in data:
    if line[-1]!='' and line[0].split('-')[1]=='08':
        result.append(float(line[-1]))

plt.figure(figsize=(10,2))
plt.plot(result,'hotpink')
plt.show()
f.close()

# %%
import csv
import matplotlib.pyplot as plt

f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
next(data)
result=[]

for line in data:
    if line[-1]!='' and line[0].split('-')[1]=='02'and line[0].split('-')[2]=='14':
        result.append(float(line[-1]))

plt.figure(figsize=(10,2))
plt.plot(result,'hotpink')
plt.show()
f.close()

# %%
import csv
f=open('seoul.csv','r',encoding='CP949')
data=csv.reader(f)
header=next(f)
print(header)

f.close()
# Out:
# 날짜,지점,평균기온(℃),최저기온(℃),최고기온(℃)

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
for line in data:
    if '2020-05-19' in line:
         print(line[2], line[3], line[4])

f.close()
# Out:
# 13 10.1 17.1

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
header=next(data)
for line in data:
    date=line[0].split('-')
    print(line[0], date)
f.close()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1950-04-28 ['1950', '04', '28']
# 1950-04-29 ['1950', '04', '29']
# 1950-04-30 ['1950', '04', '30']
# 1950-05-01 ['1950', '05', '01']
# 1950-05-02 ['1950', '05', '02']
# 1950-05-03 ['1950', '05', '03']
# 1950-05-04 ['1950', '05', '04']
# 1950-05-05 ['1950', '05', '05']
# 1950-05-06 ['1950', '05', '06']
# 1950-05-07 ['1950', '05', '07']
# 1950-05-08 ['1950', '05', '08']
# 1950-05-09 ['1950', '05', '09']
# 1950-05-10 ['1950', '05', '10']
# 1950-05-11 ['1950', '05', '11']
# 1950-05-12 ['1950', '05', '12']
# 1950-05-13 ['1950', '05', '13']
# 1950-05-14 ['1950', '05', '14']
# 1950-05-15 ['1950', '05', '15']
# 1950-05-16 ['1950', '05', '16']
# 1950-05-17 ['1950', '05', '17']
# 1950-05-18 ['1950', '05', '18']
# 1950-05-19 ['1950', '05', '19']
# 1950-05-20 ['1950', '05', '20']
# 1950-05-21 ['1950', '05', '21']
# 1950-05-22 ['1950', '05', '22']
# 1950-05-23 ['1950', '05', '23']
# 1950-05-24 ['1950', '05', '24']
# 1950-05-25 ['1950', '05', '25']
# ...

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
header=next(data)
max_temp=0

for line in data:
    if line[4]!='' and max_temp<float(line[4]): #최고기온
        max_temp=float(line[4])

print(max_temp)
f.close()
# Out:
# 39.6

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
header=next(data)
max_temp=0
min_temp=100
max_date=''
min_date=''

for line in data:
    if line[4]!='' and max_temp<float(line[4]):  #최고기온
        max_temp=float(line[4])
        max_date=line[0]

    if line[3]!='' and min_temp>float(line[3]):  #최저기온
        min_temp=float(line[3])
        min_date=line[0]

print('최고기온 날짜와 온도 : ', max_date, max_temp)
print('최저기온 날짜와 온도 : ', min_date, min_temp)
f.close()
# Out:
# 최고기온 날짜와 온도 :  2018-08-01 39.6
# 최저기온 날짜와 온도 :  1927-12-31 -23.1

# %%
import csv
f=open('2020temp.csv', 'r', encoding='cp949')
data=csv.reader(f)
header=next(data)
print(header)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
for line in data:
    print(line)
f.close()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['2007-07-25', '108', '24.7', '23.2', '26.7']
# ['2007-07-26', '108', '26.7', '23', '31.2']
# ['2007-07-27', '108', '26.9', '25.1', '29.7']
# ['2007-07-28', '108', '25.1', '24.1', '26.2']
# ['2007-07-29', '108', '24.6', '21.7', '27.2']
# ['2007-07-30', '108', '26.4', '22.2', '31.2']
# ['2007-07-31', '108', '26.4', '23.5', '29.8']
# ['2007-08-01', '108', '27.2', '25.1', '30.1']
# ['2007-08-02', '108', '27.8', '25.7', '30.2']
# ['2007-08-03', '108', '27.5', '25.2', '32.2']
# ['2007-08-04', '108', '24.5', '22.2', '26.1']
# ['2007-08-05', '108', '24.8', '22.2', '27.7']
# ['2007-08-06', '108', '25.7', '24', '29.3']
# ['2007-08-07', '108', '23.8', '22.3', '25.2']
# ['2007-08-08', '108', '25.3', '21.8', '27.7']
# ['2007-08-09', '108', '26.1', '22.2', '29.2']
# ['2007-08-10', '108', '27.7', '25.7', '31']
# ['2007-08-11', '108', '28.7', '25.5', '33']
# ['2007-08-12', '108', '26.2', '24.6', '28.1']
# ['2007-08-13', '108', '27.6', '24.8', '30.3']
# ...

# %%
import csv
import matplotlib as plt
f=open('seoul.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
max_result=[]
for line in data:
    if line[4] !='':  #최고기온 데이터가 있을 때만
        max_result.append(float(line[4]))

print(max_result)
f.close()
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
import csv
import matplotlib.pyplot as plt

f=open('2020_temp.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
date_x=[]
max_result=[]

for line in data:
    if line[0] != '': #날짜가 빈칸이 아닐때
        date_x.append(line[0])

    if line[4] != '': #최고기온이 빈칸이 아닐때
        max_result.append(float(line[4]))
# print(date_x)
# print(max_result)

plt.figure(figsize=(20, 5))
# plt.plot(date_x, max_result, 'r')
plt.plot(date_x, max_result,
         color='skyblue',
         marker='o', markerfacecolor='blue',
         markersize=6)
plt.show()
f.close()
# Out:
# ['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12', '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16', '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22', '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11', '20
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import rc

plt.rc('font', family='NanumBarunGothic') 
f=open('2020_temp.csv', 'r', encoding='cp949')
data=csv.reader(f)
next(data)
date_x=[]
max_result=[]
min_result=[]
avg_result=[]

for line in data:
    if line[0] != '': #날짜가 빈칸이 아닐때
        date=line[0].split('-')
        date_x.append(date[1]+"-"+date[2])

    if line[4] != '': #최고기온이 빈칸이 아닐때
        max_result.append(float(line[4]))

    if line[3] != '': #최저기온이 빈칸이 아닐때
        min_result.append(float(line[3]))

    if line[2] != '': #평균기온이 빈칸이 아닐때
        avg_result.append(float(line[2]))

print(date_x)
#print(max_result)
plt.figure(figsize=(20, 5))
plt.plot(date_x, max_result, 'r')
plt.plot(date_x, min_result, 'b')
plt.plot(date_x, avg_result, 'g')

plt.title('2020년 기온데이터 분석')
plt.xticks(rotation=90)
plt.show()
f.close()
# Out:
# ['01-01', '01-02', '01-03', '01-04', '01-05', '01-06', '01-07', '01-08', '01-09', '01-10', '01-11', '01-12', '01-13', '01-14', '01-15', '01-16', '01-17', '01-18', '01-19', '01-20', '01-21', '01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28', '01-29', '01-30', '01-31', '02-01', '02-02', '02-03', '02-04', '02-05', '02-06', '02-07', '02-08', '02-09', '02-10', '02-11', '02-12', '02-13', '02-14', '02-15', '02-16', '02-17', '02-18', '02-19', '02-20', '02-21', '02-22', '02-23', '02-24', '02-25', '02-26', '02-27', '02-28', '02-29', '03-01', '03-02', '03-03', '03-04', '03-05', '03-06', '03-07', '03-08', '03-09', '03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', '03-18', '03-19', '03-20', '03-21', '03-22', '03-23', '03-24', '03-25', '03-26', '03-27', '03-28', '03-29', '03-30', '03-31', '04-01', '04-02', '04-03', '04-04', '04-05', '04-06', '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13', '04-14', '04-15', '04-16', '04-17', '04-18', '04-19', '04-20'
# ...
