# %% [markdown]
# <a href="https://colab.research.google.com/github/osh9149/2025_DataScience/blob/main/2025%EB%85%84_3%ED%95%99%EB%85%84_1%ED%95%99%EA%B8%B0_%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80_%EC%97%B0%EC%8A%B5_%EC%86%8C%EB%B0%A9%EC%84%9C(%ED%98%BC%EC%9E%90%ED%95%B4%EB%B3%B4%EA%B8%B0_%EB%AC%B8%EC%A0%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 구글클래스 룸에서 전국 소방청_전국소방서 좌표현황(XY좌표), 소방청_연간화재통계 파일 다운로드
# https://classroom.google.com/c/NzU2OTE3NjQxNTA5/p/Nzc4MjA3ODEyNTQ5/details

# %% [markdown]
# #공공데이터포털에서 '소방청_전국소방서 좌표현황(XY좌표)'와 '소방청_연간화재통계'파일을 다운받아 제공함.

# %% [markdown]
# #문제1. 폰트설치(1점) 후 런타임-> 다시 시작할 것

# %%
#문제1번(1점)

# %% [markdown]
# # 문제2. 데이터 분석(numpy, pandas) 및 그래프(matplotlib), 지도 시각화(folium)를 위한 라이브러리를 호출(1점)

# %%
#문제2번(1점)

# %% [markdown]
# #문제3. #'소방청_연간화재통계' 파일을 바로 업로드할 때(업로드는 1번만 실행할 것)(1점)

# %%
#문제3번(1점)

# %% [markdown]
# #문제4. 데이터파일을(소방청_연간화재통계.csv)을 판다스 라이브러리를 이용해 읽는다.(2점)

# %%
#문제4번(2점)

# %% [markdown]
# #문제5.시도별로 그룹화하여 화재발생수를 카운트하고 '화재유형'데이터를 내림차순으로 정렬하여 새로운 데이터프레임(df1)으로 만든다.(4점)

# %%
#문제5번(4점)

# %% [markdown]
# #문제6. 데이터프레임(d1f)에서 화재 발생수가 가장 많은 지역과 가장 적은 지역을 찾아 다음과 같이 출력한다.(4점)
# 예) 전국에서 화재발생 수가 가장 많은 지역은 경기도입니다.
#    전국에서 화재발생 수가 적은 많은 지역은 세종특별자치시입니다.

# %%
#문제6번(4점)

# %% [markdown]
# #문제7. 위의 데이터프레임(df1)을 그래프로 그림처럼 시각화한다.(4점)
# ![image.png](data:image/png;base64,...)

# %%
#문제7번(4점)

# %% [markdown]
# #문제8. 데이터프레임(df)에서 '인명피해(명)소계'를 기준으로 내림차순으로 정렬한 후 df를 출력한다.(3점)

# %%
#문제8번(3점)

# %% [markdown]
# #문제9. 데이터프레임(df)에서 '인명피해(명)소계'가 가장 많은 지역과  발화요인소분류'를 찾아 다음과 같이 출력한다.(4점)
# 출력결과)전국에서 인명피해가 가장 많은 지역은 강릉시이고 발화요인은 자연적 재해입니다.

# %%
#문제9번(4점)

# %% [markdown]
# #문제10. 데이터프레임(df)에서 '재산피해소계'가 0보다 크고 '발화요인소분류'가 자연적 재해인 지역만 새로운 데이터프레임 df2로 만든다.(3점)

# %%
#문제10번(3점)

# %% [markdown]
# #문제11. 데이터프레임(df2)을 재산피해소계가 낮은 순부터 많은 순으로 정렬하여 df2를 출력한다.(3점)

# %%
#문제11번(3점)

# %% [markdown]
# #문제12. df2를 시도별로 그룹화 하고 카운트하여 df3로 만들고 df3를 화재유형에 따라 내림차순으로 정렬한다.

# %%
#문제12번(4점)

# %% [markdown]
# #문제13. 위의 데이터프레임(df3)의 시도와 화재유형으로 그림과 같이 그래프를 그린다.
# ![image.png](data:image/png;base64,...)

# %%
#문제13번(4점)

# %% [markdown]
# #문제14. 데이터프레임(df3)에서 산불 횟수가 가장 많은 지역과 가장 적은 지역의 차이를 계산하여 아래와 같이 출력한다. 이때 print문에서 지역이름은 %s로 출력하고 차이값은 %d로 출력한다.(4점)
# 예) 산불횟수가 가장 많은 전라남도 지역과 가장 적은 충청북도 지역의 횟수는 21번 입니다.

# %%
#문제14번(4점)

# %% [markdown]
# #문제15. 소방청_전국소방서 좌표현황(XY좌표).xlsx파일을 업로드한다

# %% [markdown]
# #문제16. 소방청_전국소방서 좌표현황(XY좌표).xlsx파일을 데이터프레임(df6)으로 읽는다.

# %%
#문제16번(4점)

# %% [markdown]
# #문제17. 데이터프레임(df6)에서 원하는 주소의 이름을 입력받아 해당하는 지역의 데이터만 새로운 데이터프레임(df7)로 만든다.(4점)
# 예) '서울' 입력하여 확인

# %%
#문제17번(4점)

# %% [markdown]
# #문제18. 데이터프레임(df)에서 위도 경도를 찾아 지도에 마커로 표시(zoom_start=11)하고 팝업에 학교이름이 보이도록 한다.(4점)
# 아이콘 변경 -> icon=folium.Icon(icon = 'home', color='red')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#문제18번(4점)
